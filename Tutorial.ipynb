# %%
## FOLLOWING THIS TUTORIAL:
# http://www.gregreda.com/2013/10/26/intro-to-pandas-data-structures/
# Download Sequel Pro: http://www.sequelpro.com/

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
pd.set_option('max_columns', 50)

# %%
# create a Series with an arbitrary list
s = pd.Series([7, 'Heisenberg', 3.14, -1789710578, 'Happy Eating!'])
s
# Out:
# 0                7
# 1       Heisenberg
# 2             3.14
# 3      -1789710578
# 4    Happy Eating!
# dtype: object

# %%
s = pd.Series([7, 'Heisenberg', 3.14, -1789710578, 'Happy Eating!'],
              index=['A', 'Z', 'C', 'Y', 'E'])
s
# Out:
# A                7
# Z       Heisenberg
# C             3.14
# Y      -1789710578
# E    Happy Eating!
# dtype: object

# %%
pd.Series([7, 'Heisenberg', 3.14, -1789710578, 'Happy Eating!'],index=['A', 'Z', 'C', 'Y', 'E'])
# Out:
# A                7
# Z       Heisenberg
# C             3.14
# Y      -1789710578
# E    Happy Eating!
# dtype: object

# %%
d = {'Chicago': 1000, 'New York': 1300, 'Portland': 900, 'San Francisco': 1100,
     'Austin': 450, 'Boston': None}
cities = pd.Series(d)
cities
# Out:
# Austin            450
# Boston            NaN
# Chicago          1000
# New York         1300
# Portland          900
# San Francisco    1100
# dtype: float64

# %%
cities['Boston']
# Out:
# nan

# %%
cities.isnull()
cities.notnull()
cities[cities.notnull()]
# Out:
# Austin            450
# Chicago          1000
# New York         1300
# Portland          900
# San Francisco    1100
# dtype: float64

# %%
'austin' in cities
# Out:
# False

# %%
cities / 3
# Out:
# Austin           150.000000
# Boston                  NaN
# Chicago          333.333333
# New York         433.333333
# Portland         300.000000
# San Francisco    366.666667
# dtype: float64

# %%
np.sqrt(cities)
np.square(cities)
# Out:
# Austin            202500
# Boston               NaN
# Chicago          1000000
# New York         1690000
# Portland          810000
# San Francisco    1210000
# dtype: float64

# %%
###
# NOW LET'S WORK WITH DATA FRAMES
###

# %%
data = {'year': [2010, 2011, 2012, 2011, 2012, 2010, 2011, 2012],
        'team': ['Bears', 'Bears', 'Bears', 'Packers', 'Packers', 'Lions', 'Lions', 'Lions'],
        'wins': [11, 8, 10, 15, 11, 6, 10, 4],
        'losses': [5, 8, 6, 1, 5, 10, 6, 12]}
football = pd.DataFrame(data, columns=['year', 'team', 'wins', 'losses'])
print football
# Out:
#    year     team  wins  losses
# 0  2010    Bears    11       5
# 1  2011    Bears     8       8
# 2  2012    Bears    10       6
# 3  2011  Packers    15       1
# 4  2012  Packers    11       5
# 5  2010    Lions     6      10
# 6  2011    Lions    10       6
# 7  2012    Lions     4      12

# %%
#import os
#os.system('wget http://baseball-reference.com/players/r/riverma01.shtml')
# !wget http://baseball-reference.com/players/r/riverma01.shtml
# !head -n 5 riverma01.shtml
# Out:
# --2013-10-27 20:26:03--  http://baseball-reference.com/players/r/riverma01.shtml
# Resolving baseball-reference.com... 66.35.36.83
# Connecting to baseball-reference.com|66.35.36.83|:80...
# connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: http://www.baseball-reference.com/players/r/riverma01.shtml [following]
# --2013-10-27 20:26:03--  http://www.baseball-reference.com/players/r/riverma01.shtml
# Resolving www.baseball-reference.com... 66.35.36.83
# Reusing existing connection to baseball-reference.com:80.
# HTTP request sent, awaiting response...
# 200 OK
# Length: unspecified [text/html]
# Saving to: ‘riverma01.shtml.3’
#
#     [<=>                                    ] 0           --.-K/s
#     [ <=>                                   ] 67,713       307KB/s
#     [   <=>                                 ] 430,035      826KB/s   in 0.5s
#
# 2013-10-27 20:26:04 (826 KB/s) - ‘riverma01.shtml.3’ saved [430035]
# <!DOCTYPE html>
# ...

# %%
from_csv = pd.read_clipboard()
from_csv
# Out:
#     Year  Age   Tm  Lg  W  L   W-L%   ERA   G  GS  GF  CG  SHO  SV     IP   H  \
# 0   1995   25  NYY  AL  5  3  0.625  5.51  19  10   2   0    0   0   67.0  71
# 1   1996   26  NYY  AL  8  3  0.727  2.09  61   0  14   0    0   5  107.2  73
# 2   1997   27  NYY  AL  6  4  0.600  1.88  66   0  56   0    0  43   71.2  65
# 3   1998   28  NYY  AL  3  0  1.000  1.91  54   0  49   0    0  36   61.1  48
# 4   1999   29  NYY  AL  4  3  0.571  1.83  66   0  63   0    0  45   69.0  43
# 5   2000   30  NYY  AL  7  4  0.636  2.85  66   0  61   0    0  36   75.2  58
# 6   2001   31  NYY  AL  4  6  0.400  2.34  71   0  66   0    0  50   80.2  61
# 7   2002   32  NYY  AL  1  4  0.200  2.74  45   0  37   0    0  28   46.0  35
# 8   2003   33  NYY  AL  5  2  0.714  1.66  64   0  57   0    0  40   70.2  61
# 9   2004   34  NYY  AL  4  2  0.667  1.94  74   0  69   0    0  53   78.2  65
# 10  2005   35  NYY  AL  7  4  0.636  1.38  71   0  67   0    0  43   78.1  50
# ...

# %%
import xlrd
football.to_excel('football.xlsx', index=False)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-50-16ec83a5754d> in <module>()
#       1 import xlrd
# ----> 2 football.to_excel('football.xlsx', index=False)
#
# /Users/witoff/anaconda/python.app/Contents/lib/python2.7/site-packages/pandas/core/frame.pyc in to_excel(self, excel_writer, sheet_name, na_rep, float_format, cols, header, index, index_label, startrow, startcol)
#    1454         need_save = False
#    1455         if isinstance(excel_writer, basestring):
# -> 1456             excel_writer = ExcelWriter(excel_writer)
#    1457             need_save = True
#    1458
#
# /Users/witoff/anaconda/python.app/Contents/lib/python2.7/site-packages/pandas/io/excel.pyc in __init__(self, path)
#     348             self.fm_date = xlwt.easyxf(num_format_str='YYYY-MM-DD')
#     349         else:
# --> 350             from openpyxl.workbook import Workbook
# ...

# %%
baseball = from_csv
baseball.head()
# Out:
#    Year  Age   Tm  Lg  W  L   W-L%   ERA   G  GS  GF  CG  SHO  SV     IP   H  \
# 0  1995   25  NYY  AL  5  3  0.625  5.51  19  10   2   0    0   0   67.0  71
# 1  1996   26  NYY  AL  8  3  0.727  2.09  61   0  14   0    0   5  107.2  73
# 2  1997   27  NYY  AL  6  4  0.600  1.88  66   0  56   0    0  43   71.2  65
# 3  1998   28  NYY  AL  3  0  1.000  1.91  54   0  49   0    0  36   61.1  48
# 4  1999   29  NYY  AL  4  3  0.571  1.83  66   0  63   0    0  45   69.0  43
#
#     R  ER  HR  BB  IBB   SO  HBP  BK  WP   BF  ERA+   WHIP  H/9  HR/9  BB/9  \
# 0  43  41  11  30    0   51    2   1   0  301    84  1.507  9.5   1.5   4.0
# 1  25  25   1  34    3  130    2   0   1  425   240  0.994  6.1   0.1   2.8
# 2  17  15   5  20    6   68    0   0   2  301   239  1.186  8.2   0.6   2.5
# 3  13  13   3  17    1   36    1   0   0  246   233  1.060  7.0   0.4   2.5
# 4  15  14   2  18    3   52    3   1   2  268   257  0.884  5.6   0.3   2.3
#
#    SO/9  SO/BB           Awards
# ...
